# %%
import pandas as pd

# %%
ca=pd.read_excel('CA.xlsx')
ca
# Out:
#       발생년      발생년월일시  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 0    2012  2012011212  주간  목     1     1     0     0       0    충남  ...
# 1    2012  2012010507  주간  목     1     1     0     0       0    충남  ...
# 2    2012  2012012800  야간  토     1     3     1     1       0    충남  ...
# 3    2012  2012010714  주간  토     3     7     2     2       0    충남  ...
# 4    2012  2012020506  주간  일     1     4     3     0       0    충남  ...
# ..    ...         ...  .. ..   ...   ...   ...   ...     ...   ...  ...
# 505  2021  2021092804  야간  화     1     1     0     0       0    충남  ...
# 506  2021  2021101811  주간  월     1     1     0     0       0    충남  ...
# 507  2021  2021110306  주간  수     1     1     0     0       0    충남  ...
# 508  2021  2021120510  주간  일     1     1     0     0       0    충남  ...
# 509  2021  2021120719  야간  화     1     1     0     0       0    충남  ...
#
#     당사자종별_1당_대분류 당사자종별_2당_대분류 발생위치X_UTMK 발생위치Y_UTMK          경도         위도  \
# ...

# %%
a=pd.read_excel('.././표준화 점수.xlsx')


a.to_excel('교통사고 표준화점수.xlsx', index=False)  # Set index=False to exclude row numbers
